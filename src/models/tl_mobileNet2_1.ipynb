# %% [markdown]
# <h1>human organ classification </h1>
# <h2> C-NN model<h3> [transfer learn on MobileNetV2 model]</h3></h2>

# %% [markdown]
# call to packages & libraries

# %%
from tensorflow import keras
from datetime import datetime

from src.sup.evaluation import *
from src.sup.support import *
from src.sup.test_set_eval import *

from tensorflow.keras.optimizers import RMSprop,SGD,Adam
from tensorflow.keras.layers import Dense,BatchNormalization,Dropout
from tensorflow.keras.layers import Conv2D,MaxPool2D,Flatten
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import Model

# %%
model_name = "mobileNet_v2_transfer_learn_2.1"

# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# call inline plt.

# %%
# Clear any logs from previous runs
# !rm -rf ./logs/

# %% [markdown]
# callout dataset

# %%
classes = ['Heart','Brain','Eye','Kidney','Skull']
root_dir = '../../datasets/'
train_dir = os.path.join(root_dir,'train/')
validation_dir = os.path.join(root_dir,'validation/')
tr_heart_dir,tr_brain_dir,tr_eye_dir,tr_kidney_dir,tr_skull_dir = path_update(train_dir,classes)
vl_heart_dir,vl_brain_dir,vl_eye_dir,vl_kidney_dir,vl_skull_dir = path_update(validation_dir,classes)

# %% [markdown]
# take a glance at training dataset

# %%
plot_sample_of_img(4,4,os.listdir(tr_heart_dir)+os.listdir(tr_eye_dir))

# %% [markdown]
# ImageGenator - autolabelling, and categorizing.

# %%
train_gen_tmp = ImageDataGenerator(rescale=1./255,
      width_shift_range=0.2,
      height_shift_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')

validation_gen_tmp = ImageDataGenerator(rescale=1/225.)

train_gen = train_gen_tmp.flow_from_directory(train_dir,
                                              target_size=(224,224),
                                              color_mode='rgb',
                                              class_mode='categorical',
                                              batch_size= 20,
                                              shuffle=True,
                                              seed=42)

validation_gen = validation_gen_tmp.flow_from_directory(validation_dir,
                                              target_size=(224,224),
                                              color_mode='rgb',
                                              class_mode='categorical',
                                              batch_size= 20,
                                              shuffle=True,
                                              seed=42)

STEP_SIZE_TRAIN=train_gen.n//train_gen.batch_size
STEP_SIZE_VALID=validation_gen.n//validation_gen.batch_size

clToInt_dict = train_gen.class_indices
clToInt_dict = dict((k,v) for v,k in clToInt_dict.items())
# Out:
# Found 2035 images belonging to 5 classes.
# Found 164 images belonging to 5 classes.

# %% [markdown]
# define the model

# %%
weight_path = '../../h5_files/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5'

pre_model = MobileNetV2(input_shape=(224,224,3),
                    weights = None,
                    include_top = True)

pre_model.load_weights(weight_path)
#model.summary()

for layer in pre_model.layers:
    layer.trainable = False

conn_layer = pre_model.get_layer('block_12_add')
conn_output = conn_layer.output

x = Conv2D(256,(3,3),activation='relu')(conn_output)
x = MaxPool2D(2,2)(x)
x = Flatten()(x)
#x = Dense(256,activation='relu')(x)
#x = Dropout(0.2)(x)
x = Dense(128,activation='relu')(x)
#x = Dropout(0.2)(x)
#x = BatchNormalization()(x)
x = Dense(5,activation='softmax')(x)

model = Model(pre_model.input,x)

#model.summary()

# %% [markdown]
# compile the model

# %%
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# save the log

# %%
# Define the Keras TensorBoard callback.
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")+'/'

if not os.path.exists(logdir):
    os.mkdir(logdir)

#print(datetime.now().strftime("%Y%m%d%H%M%S"))
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1, profile_batch = 100000000)

# %% [markdown]
# fit & train the model.

# %%
history = model.fit(train_gen,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=validation_gen,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=15,
                    verbose=1,
                    callbacks= [tensorboard_callback])
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 101 steps, validate for 8 steps
# Epoch 1/15
# 101/101 [==============================] - 23s 229ms/step - loss: 3.9687 - accuracy: 0.6809 - val_loss: 1.7284 - val_accuracy: 0.7437
# Epoch 2/15
#  - ETA: 3s - loss: 0.5285 - accuracy: 0.8776
# Epoch 3/15
# 101/101 [==============================] - 21s 212ms/step - loss: 0.3426 - accuracy: 0.9256 - val_loss: 0.3729 - val_accuracy: 0.9375
# Epoch 4/15
#  - ETA: 14s - loss: 0.4767 - accuracy: 0.9130
# Epoch 5/15
# 101/101 [==============================] - 22s 214ms/step - loss: 0.2646 - accuracy: 0.9439 - val_loss: 0.8859 - val_accuracy: 0.9375
# Epoch 6/15
# 101/101 [==============================] - 23s 225ms/step - loss: 0.2464 - accuracy: 0.9419 - val_loss: 0.6624 - val_accuracy: 0.9000
# Epoch 7/15
# 101/101 [==============================] - 22s 222ms/step - loss: 0.1750 - accuracy: 0.9568 - val_loss: 0.4941 - val_accuracy: 0.9375
# Epoch 8/15
# 101/101 [==============================] - 22s 221ms/step - loss: 0.1265 - accuracy: 0.9658 - val_loss: 1.4303 - val_accuracy: 0.8625
# Epoch 9/15
# 101/101 [==============================] - 22s 221ms/step - loss: 0.1400 - accuracy: 0.9638 - val_loss: 0.7853 - val_accuracy: 0.9000
# Epoch 10/15
# 101/101 [==============================] - 22s 216ms/step - loss: 0.1722 - accuracy: 0.9598 - val_loss: 0.5025 - val_accuracy: 0.9000
# Epoch 11/15
# 101/101 [==============================] - 22s 219ms/step - loss: 0.0870 - accuracy: 0.9752 - val_loss: 0.3097 - val_accuracy: 0.9312
# Epoch 12/15
# 101/101 [==============================] - 22s 222ms/step - loss: 0.1179 - accuracy: 0.9722 - val_loss: 0.3083 - val_accuracy: 0.9438
# Epoch 13/15
#  - ETA: 7s - loss: 0.0774 - accuracy: 0.9818
# Epoch 14/15
# 101/101 [==============================] - 23s 224ms/step - loss: 0.0536 - accuracy: 0.9861 - val_loss: 0.4047 - val_accuracy: 0.9250
# Epoch 15/15
# 101/101 [==============================] - 23s 228ms/step - loss: 0.0507 - accuracy: 0.9846 - val_loss: 0.4393 - val_accuracy: 0.9250

# %% [markdown]
# visualize layer process in cnn

# %%
#visualize_model(model,img_path)

# %% [markdown]
# instant evaluation

# %%
#call to the tensorboard
#%tensorboard --logdir ./logs/fit/
#look at training model performance
acc_n_loss(history)

#model.evaluate_generator(validation_gen,
#                         steps=STEP_SIZE_VALID)

# %% [markdown]
# evaluate the model on test set.

# %%
model_path = '../../h5_files/models/20200816005012mobileNet_v2_transfer_learn.h5'
model_weight_path = '../../h5_files/weights/20200816005012mobileNet_v2_transfer_learn.h5'

model = load_model(model_path)
model.load_weights(model_weight_path)
y_pred,y_test = test_eval(model,classes)
plot_confusion_metrix(y_test,y_pred,classes)
ROC_classes(6,y_test,y_pred,classes)

# %% [markdown]
#  save the model in .h5 file

# %%
model_path,model_weight_path = save(model,datetime.now().strftime("%Y%m%d%H%M%S")+model_name+'.h5')

# %% [markdown]
# make prediction on random images

# %%
model_path = '../../h5_files/models/20200816005012mobileNet_v2_transfer_learn.h5'
model_weight_path = '../../h5_files/weights/20200816005012mobileNet_v2_transfer_learn.h5'
img_path = '../../datasets/validation/../../datasets/validation/Other/11.jpg'
rnd_predict(model_path,model_weight_path,img_path,clToInt_dict)
