# %% [markdown]
# <h1>human organ classification </h1>
# <h2> C-NN model<h3> [transfer learn on MobileNetV2 model]</h3></h2>

# %% [markdown]
# call to packages & libraries

# %%
from tensorflow import keras
from datetime import datetime

from src.sup.evaluation import *
from src.sup.support import *
from src.sup.test_set_eval import *

from tensorflow.keras.optimizers import RMSprop,SGD,Adam
from tensorflow.keras.layers import Dense,BatchNormalization,Dropout
from tensorflow.keras.layers import Conv2D,MaxPool2D,Flatten
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import Model

# %%
model_name = "mobileNet_v2_transfer_learn_1.1"

# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# call inline plt.

# %%
# Clear any logs from previous runs
# !rm -rf ./logs/

# %% [markdown]
# callout dataset

# %%
classes = ['Heart','Brain','Eye','Kidney','Skull','Other']
root_dir = '../../datasets/'
train_dir = os.path.join(root_dir,'train/')
validation_dir = os.path.join(root_dir,'validation/')
tr_heart_dir,tr_brain_dir,tr_eye_dir,tr_kidney_dir,tr_skull_dir,tr_other_dir = path_update(train_dir,classes)
vl_heart_dir,vl_brain_dir,vl_eye_dir,vl_kidney_dir,vl_skull_dir,vl_other_dir = path_update(validation_dir,classes)

# %% [markdown]
# take a glance at training dataset

# %%
plot_sample_of_img(4,4,os.listdir(tr_heart_dir)+os.listdir(tr_eye_dir))

# %% [markdown]
# ImageGenator - autolabelling, and categorizing.

# %%
train_gen_tmp = ImageDataGenerator(rescale=1./255,
      width_shift_range=0.2,
      height_shift_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')

validation_gen_tmp = ImageDataGenerator(rescale=1/225.)

train_gen = train_gen_tmp.flow_from_directory(train_dir,
                                              target_size=(224,224),
                                              color_mode='rgb',
                                              class_mode='categorical',
                                              batch_size= 20,
                                              shuffle=True,
                                              seed=42)

validation_gen = validation_gen_tmp.flow_from_directory(validation_dir,
                                              target_size=(224,224),
                                              color_mode='rgb',
                                              class_mode='categorical',
                                              batch_size= 20,
                                              shuffle=True,
                                              seed=42)

STEP_SIZE_TRAIN=train_gen.n//train_gen.batch_size
STEP_SIZE_VALID=validation_gen.n//validation_gen.batch_size

clToInt_dict = train_gen.class_indices
clToInt_dict = dict((k,v) for v,k in clToInt_dict.items())
# Out:
# Found 2803 images belonging to 6 classes.
# Found 247 images belonging to 6 classes.

# %% [markdown]
# define the model

# %%
weight_path = '../../h5_files/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5'

pre_model = MobileNetV2(input_shape=(224,224,3),
                    weights = None,
                    include_top = True)

pre_model.load_weights(weight_path)
#model.summary()

for layer in pre_model.layers:
    layer.trainable = False

conn_layer = pre_model.get_layer('block_12_add')
conn_output = conn_layer.output

x = Conv2D(256,(3,3),activation='relu')(conn_output)
x = MaxPool2D(2,2)(x)
x = Flatten()(x)
#x = Dense(256,activation='relu')(x)
#x = Dropout(0.2)(x)
x = Dense(128,activation='relu')(x)
#x = Dropout(0.2)(x)
#x = BatchNormalization()(x)
x = Dense(6,activation='softmax')(x)

model = Model(pre_model.input,x)

#model.summary()

# %% [markdown]
# compile the model

# %%
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# save the log

# %%
# Define the Keras TensorBoard callback.
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")+'/'

if not os.path.exists(logdir):
    os.mkdir(logdir)

#print(datetime.now().strftime("%Y%m%d%H%M%S"))
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1, profile_batch = 100000000)

# %% [markdown]
# fit & train the model.

# %%
history = model.fit(train_gen,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=validation_gen,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=30,
                    verbose=1,
                    callbacks= [tensorboard_callback])
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 140 steps, validate for 12 steps
# Epoch 1/30
# 140/140 [==============================] - 31s 218ms/step - loss: 2.6756 - accuracy: 0.6231 - val_loss: 0.7191 - val_accuracy: 0.7333
# Epoch 2/30
# 140/140 [==============================] - 29s 208ms/step - loss: 0.5752 - accuracy: 0.8031 - val_loss: 0.4535 - val_accuracy: 0.8333
# Epoch 3/30
# 140/140 [==============================] - 31s 221ms/step - loss: 0.5366 - accuracy: 0.8279 - val_loss: 0.5249 - val_accuracy: 0.8000
# Epoch 4/30
# 140/140 [==============================] - 32s 229ms/step - loss: 0.4840 - accuracy: 0.8376 - val_loss: 0.7944 - val_accuracy: 0.7792
# Epoch 5/30
# 140/140 [==============================] - 32s 228ms/step - loss: 0.4241 - accuracy: 0.8613 - val_loss: 0.7912 - val_accuracy: 0.7875
# Epoch 6/30
# 140/140 [==============================] - 32s 226ms/step - loss: 0.3761 - accuracy: 0.8753 - val_loss: 0.4456 - val_accuracy: 0.8583
# Epoch 7/30
# 140/140 [==============================] - 31s 225ms/step - loss: 0.3550 - accuracy: 0.8785 - val_loss: 0.5227 - val_accuracy: 0.8458
# Epoch 8/30
#  - ETA: 17s - loss: 0.3504 - accuracy: 0.8828
# Epoch 9/30
# 140/140 [==============================] - 38s 271ms/step - loss: 0.3422 - accuracy: 0.8861 - val_loss: 0.6008 - val_accuracy: 0.8125
# Epoch 10/30
#  - ETA: 24s - loss: 0.4564 - accuracy: 0.8731
# Epoch 11/30
# 140/140 [==============================] - 36s 259ms/step - loss: 0.2744 - accuracy: 0.9109 - val_loss: 0.3812 - val_accuracy: 0.8792
# Epoch 12/30
#  - ETA: 10s - loss: 0.2482 - accuracy: 0.9161
# Epoch 13/30
# 140/140 [==============================] - 31s 225ms/step - loss: 0.2470 - accuracy: 0.9181 - val_loss: 0.4811 - val_accuracy: 0.8542
# Epoch 14/30
# 140/140 [==============================] - 32s 228ms/step - loss: 0.2501 - accuracy: 0.9213 - val_loss: 0.4538 - val_accuracy: 0.8500
# Epoch 15/30
# 140/140 [==============================] - 32s 230ms/step - loss: 0.2012 - accuracy: 0.9314 - val_loss: 0.4121 - val_accuracy: 0.8542
# Epoch 16/30
# 140/140 [==============================] - 33s 235ms/step - loss: 0.2115 - accuracy: 0.9335 - val_loss: 0.4143 - val_accuracy: 0.8292
# Epoch 17/30
# 140/140 [==============================] - 36s 257ms/step - loss: 0.1818 - accuracy: 0.9368 - val_loss: 0.5436 - val_accuracy: 0.8292
# Epoch 18/30
# 140/140 [==============================] - 34s 241ms/step - loss: 0.1902 - accuracy: 0.9400 - val_loss: 0.5520 - val_accuracy: 0.8292
# Epoch 19/30
# 140/140 [==============================] - 34s 246ms/step - loss: 0.1917 - accuracy: 0.9324 - val_loss: 0.4642 - val_accuracy: 0.8500
# Epoch 20/30
# 140/140 [==============================] - 33s 235ms/step - loss: 0.1805 - accuracy: 0.9454 - val_loss: 0.7554 - val_accuracy: 0.8167
# Epoch 21/30
# 140/140 [==============================] - 44s 313ms/step - loss: 0.1431 - accuracy: 0.9558 - val_loss: 0.5839 - val_accuracy: 0.8292
# Epoch 22/30
# 140/140 [==============================] - 44s 313ms/step - loss: 0.2092 - accuracy: 0.9346 - val_loss: 0.4750 - val_accuracy: 0.8917
# Epoch 23/30
# 140/140 [==============================] - 46s 327ms/step - loss: 0.2414 - accuracy: 0.9271 - val_loss: 0.5058 - val_accuracy: 0.8375
# Epoch 24/30
# 140/140 [==============================] - 43s 307ms/step - loss: 0.1692 - accuracy: 0.9439 - val_loss: 0.5252 - val_accuracy: 0.8500
# Epoch 25/30
# 140/140 [==============================] - 44s 315ms/step - loss: 0.1393 - accuracy: 0.9533 - val_loss: 0.4832 - val_accuracy: 0.8667
# Epoch 26/30
# 140/140 [==============================] - 47s 332ms/step - loss: 0.1408 - accuracy: 0.9511 - val_loss: 0.5154 - val_accuracy: 0.8375
# Epoch 27/30
# 140/140 [==============================] - 45s 322ms/step - loss: 0.1557 - accuracy: 0.9511 - val_loss: 0.4046 - val_accuracy: 0.8792
# Epoch 28/30
# 140/140 [==============================] - 43s 309ms/step - loss: 0.1609 - accuracy: 0.9501 - val_loss: 0.6267 - val_accuracy: 0.8167
# Epoch 29/30
# 140/140 [==============================] - 43s 310ms/step - loss: 0.1309 - accuracy: 0.9547 - val_loss: 0.8078 - val_accuracy: 0.8208
# Epoch 30/30
# 140/140 [==============================] - 43s 305ms/step - loss: 0.1567 - accuracy: 0.9508 - val_loss: 2.0891 - val_accuracy: 0.6917

# %% [markdown]
# visualize layer process in cnn

# %%
#visualize_model(model,img_path)

# %% [markdown]
# instant evaluation

# %%
#call to the tensorboard
#%tensorboard --logdir ./logs/fit/
#look at training model performance
acc_n_loss(history)

#model.evaluate_generator(validation_gen,
#                         steps=STEP_SIZE_VALID)

# %% [markdown]
# evaluate the model on test set.

# %%
model_path = '../../h5_files/models/20200816005012mobileNet_v2_transfer_learn.h5'
model_weight_path = '../../h5_files/weights/20200816005012mobileNet_v2_transfer_learn.h5'

model = load_model(model_path)
model.load_weights(model_weight_path)
y_pred,y_test = test_eval(model,classes)
plot_confusion_metrix(y_test,y_pred,classes)
ROC_classes(6,y_test,y_pred,classes)

# %% [markdown]
#  save the model in .h5 file

# %%
model_path,model_weight_path = save(model,datetime.now().strftime("%Y%m%d%H%M%S")+model_name+'.h5')

# %% [markdown]
# make prediction on random images

# %%
model_path = '../../h5_files/models/20200816005012mobileNet_v2_transfer_learn.h5'
model_weight_path = '../../h5_files/weights/20200816005012mobileNet_v2_transfer_learn.h5'
img_path = '../../datasets/validation/../../datasets/validation/Other/11.jpg'
rnd_predict(model_path,model_weight_path,img_path,clToInt_dict)
